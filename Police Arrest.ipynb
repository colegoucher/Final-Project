# %%
import pandas as pd 
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
arrest = pd.read_csv("Arrest.csv")
pd.set_option('display.max_rows', None)
labels = (arrest["INCIDENTNEIGHBORHOOD"].value_counts())
print(labels)
# Out:
# Central Business District      4238
# South Side Flats               3377
# Carrick                        2297
# East Allegheny                 2153
# Homewood South                 2044
# Homewood North                 1931
# East Liberty                   1848
# Marshall-Shadeland             1489
# Bluff                          1458
# Mount Washington               1413
# Hazelwood                      1364
# Brookline                      1346
# Lincoln-Lemington-Belmar       1318
# Knoxville                      1300
# Sheraden                       1255
# Allegheny Center               1227
# Beechview                      1166
# East Hills                     1158
# Brighton Heights               1093
# Perry South                    1038
# Bloomfield                      968
# Shadyside                       944
# Allentown                       930
# Middle Hill                     919
# Larimer                         865
# Central North Side              827
# Squirrel Hill South             808
# Crawford-Roberts                807
# North Shore                     791
# Fineview                        789
# South Side Slopes               789
# Homewood West                   752
# Garfield                        703
# Spring Hill-City View           702
# Northview Heights               696
# Bedford Dwellings               653
# Elliott                         650
# Perry North                     585
# Crafton Heights                 585
# Highland Park                   548
# Greenfield                      531
# Central Oakland                 511
# Strip District                  492
# Beltzhoover                     489
# Manchester                      458
# Chateau                         447
# North Oakland                   433
# Troy Hill                       427
# Central Lawrenceville           425
# Upper Hill                      364
# South Oakland                   345
# Overbrook                       319
# West Oakland                    311
# Outside City                    309
# California-Kirkbride            304
# Arlington                       302
# Point Breeze                    297
# South Shore                     293
# Terrace Village                 292
# Banksville                      288
# Squirrel Hill North             284
# West End                        280
# Point Breeze North              277
# Lower Lawrenceville             262
# Bon Air                         260
# Westwood                        222
# Lincoln Place                   222
# Stanton Heights                 219
# Spring Garden                   213
# Esplen                          198
# Duquesne Heights                187
# Upper Lawrenceville             187
# Morningside                     185
# Friendship                      168
# Glen Hazel                      164
# Polish Hill                     162
# Arlington Heights               153
# Allegheny West                  127
# Windgap                         123
# Mount Oliver                    122
# Fairywood                       121
# Hays                            117
# Golden Triangle/Civic Arena      83
# Oakwood                          80
# Summer Hill                      74
# Outside State                    64
# Outside County                   55
# St. Clair                        53
# East Carnegie                    48
# Chartiers City                   44
# Swisshelm Park                   42
# New Homestead                    39
# Ridgemont                        37
# Regent Square                    36
# Central Northside                23
# Mt. Oliver Boro                  18
# Troy Hill-Herrs Island            6
# Mt. Oliver Neighborhood           2
# Name: INCIDENTNEIGHBORHOOD, dtype: int64

# %%
#Data set for the whole neighborhood. 
#label = label.sort_values(by=["Number of arrests"], ascending=True)
labels = (arrest["INCIDENTNEIGHBORHOOD"].value_counts())
fig, ax = plt.subplots(figsize=(20, 6))
colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink', 'brown', 'gray', 'olive', 'cyan']
bar_width = .5
labels.plot.bar(width = bar_width, ax=ax, color=colors)
plt.xlabel('Neighborhoods')
plt.ylabel('Number of Arrests')
plt.title('All the Neighborhoods by Numbers of Arrests ')
plt.show()

# %%
#Data set for the top 10 most arrest neighborhood. 
top_10 = (arrest["INCIDENTNEIGHBORHOOD"].value_counts()).iloc[:10]
fig, ax = plt.subplots(figsize=(20, 6))
colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink', 'brown', 'gray', 'olive', 'cyan']
graph = top_10.plot.bar(color = colors)
# Adding labels
plt.xlabel('Neighborhoods')
plt.ylabel('Number of Arrests')
plt.title('Top 10 Neighborhoods by Most Number of Arrests')
plt.show()

# %%
#Data set for the top 10 least arrested neighborhoods. 

least_10 = (arrest["INCIDENTNEIGHBORHOOD"].value_counts()).iloc[-10:]
fig, ax = plt.subplots(figsize=(20, 6))
colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink', 'brown', 'gray', 'olive', 'cyan']
least_10.plot.bar(color=colors)
plt.xlabel('Neighborhoods')
plt.ylabel('Number of Arrests')
plt.title('Top 10 Neighborhoods by Least Number of Arrests')
plt.show()
